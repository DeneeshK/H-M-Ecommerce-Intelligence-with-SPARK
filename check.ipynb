# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, when
from pyspark.ml.feature import VectorAssembler, StringIndexer
from pyspark.ml.classification import GBTClassifier
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

from scripts.etl.spark_config import get_spark_session, stop_spark_session, PATHS

spark = get_spark_session("Churn_Prediction_Model")
# Out:
# 🔧 Detected 6 CPU cores
#  Setting default parallelism to 12
# 26/02/19 21:56:39 WARN Utils: Your hostname, pc-365M resolves to a loopback address: 127.0.1.1; using 192.168.220.3 instead (on interface enp7s0)
# 26/02/19 21:56:39 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/19 21:56:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SparkSession created: Churn_Prediction_Model
# Spark UI available at: http://localhost:4040
# Spark Version: 3.5.0

# %%
data_path= PATHS["processed_data"]

# %%
train_df = spark.read.parquet(f"{data_path}/churn_train_v1")

# %%
train_df.show(5)
# Out:
# +------------------+--------------------+------------------+-------------------+---------------+--------------------+---------------+-------------------+--------------------+------------------------+--------------------+--------------------+--------------------------+--------------------------+------------------+-------------------+----------+----+----------------------+
# |club_member_status|         customer_id|last_purchase_date|first_purchase_date|total_purchases|unique_shopping_days|unique_products|        total_spend|     avg_order_value|days_since_last_purchase|customer_tenure_days|  purchase_frequency|avg_days_between_purchases|std_days_between_purchases|      online_ratio|      weekend_ratio|is_churned| age|fashion_news_frequency|
# +------------------+--------------------+------------------+-------------------+---------------+--------------------+---------------+-------------------+--------------------+------------------------+--------------------+--------------------+--------------------------+--------------------------+------------------+-------------------+----------+----+----------------------+
# |            ACTIVE|00000dbacae5abe5e...|        2020-03-21|         2018-12-27|             20|                   9|             18| 0.5981525423728813|0.029907627118644066|                      95|                 545| 0.03663003663003663|                     56.25|         44.71417161099088|               0.6|               0.45|         0|49.0|                  NONE|
# |            ACTIVE|0000423b00ade9141...|        2020-04-22|         2018-09-21|             85|                  22|             63|  2.574830508474576|0.030292123629112662|                      63|                 642|  0.1321928460342146|        27.571428571428573|        31.894468844254842|0.9529411764705882|0.10588235294117647|         0|25.0|                  NONE|
# |            ACTIVE|00006413d8573cd20...|        2020-06-03|         2018-10-12|              9|                   5|              8|0.34094915254237285| 0.03788323917137476|                      21|                 621|0.014469453376205787|                     150.0|        102.12410750324007|0.7777777777777778|                0.0|         0|52.0|             Regularly|
# |            ACTIVE|000064249685c1155...|        2019-10-02|         2019-10-02|              3|                   1|              3|0.10164406779661016|0.033881355932203386|                     266|                 266|0.011235955056179775|                     999.0|                       0.0|               1.0|                0.0|         1|32.0|                  NONE|
# |            ACTIVE|0000757967448a6cb...|        2019-10-22|         2019-06-04|              4|                   2|              4|0.08976271186440678|0.022440677966101694|                     246|                 386|  0.0103359173126615|                     140.0|                       0.0|               1.0|                0.0|         0|20.0|                  NONE|
# +------------------+--------------------+------------------+-------------------+---------------+--------------------+---------------+-------------------+--------------------+------------------------+--------------------+--------------------+--------------------------+--------------------------+------------------+-------------------+----------+----+----------------------+
# only showing top 5 rows

# %%
train_df.printSchema()
# Out:
# root
#  |-- club_member_status: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- last_purchase_date: date (nullable = true)
#  |-- first_purchase_date: date (nullable = true)
#  |-- total_purchases: long (nullable = true)
#  |-- unique_shopping_days: long (nullable = true)
#  |-- unique_products: long (nullable = true)
#  |-- total_spend: double (nullable = true)
#  |-- avg_order_value: double (nullable = true)
#  |-- days_since_last_purchase: integer (nullable = true)
#  |-- customer_tenure_days: integer (nullable = true)
#  |-- purchase_frequency: double (nullable = true)
#  |-- avg_days_between_purchases: double (nullable = true)
#  |-- std_days_between_purchases: double (nullable = true)
#  |-- online_ratio: double (nullable = true)
#  |-- weekend_ratio: double (nullable = true)
#  |-- is_churned: integer (nullable = true)
#  |-- age: double (nullable = true)
#  |-- fashion_news_frequency: string (nullable = true)
